# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
n_vals = [100,200,400,800,1600]
k_types = ['log2(n)', 'log2(n)^2', 'n/5']
k_values = [np.round(np.log2(n_vals)), np.round(np.log2(n_vals)**2), np.round(n_vals/5)]

k_values
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 n_vals = [100,200,400,800,1600]
#       2 k_types = ['log2(n)', 'log2(n)^2', 'n/5']
# ----> 3 k_values = [np.round(np.log2(n_vals)), np.round(np.log2(n_vals)**2), np.round(n_vals/5)]
#       5 k_values
#
# TypeError: unsupported operand type(s) for /: 'list' and 'int'
